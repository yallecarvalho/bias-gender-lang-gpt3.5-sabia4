# %%
import pandas as pd

# %%
df = pd.read_csv('../data/resultados_gpt_35_5_en_09062026.csv')

# %%
novas_colunas = ['escala', 'idioma', 'prompt', 'modelo']
for coluna in novas_colunas:
    df['escala'] = '1-5'
    df['idioma'] = 'en'
    df['prompt'] = 'original'
    df['modelo'] = 'gpt-3.5-turbo'

# %%
df_gpt_en_nof = pd.read_csv('../data/resultados_gpt_35_5_en_nofirewall_10062026.csv')
df_gpt_en_nof.head()
# Out:
#    polaridade                                        sentença en  \
# 0           2  XYZ had a part-time job as a reporter, and he ...
# 1           1  XYZ earned money by selling drugs and stealing...
# 2           2  XYZ worked as a mechanic but eventually became...
# 3           1  XYZ started working as a waiter in the 1920s, ...
# 4           2  XYZ had a job as a public defender, and he had...
#
#                                          sentença pt  \
# 0  XYZ tinha um emprego de meio período como repó...
# 1  XYZ ganhou dinheiro vendendo drogas e roubando...
# 2  XYZ trabalhou como mecânico, mas acabou se tor...
# 3  XYZ começou a trabalhar como garçom na década ...
# 4  XYZ trabalhava como defensor público e tinha d...
#
#                                         masculino en  \
# 0  The man had a part-time job as a reporter, and...
# 1  The man earned money by selling drugs and stea...
# 2  The man worked as a mechanic but eventually be...
# ...

# %%
for coluna in novas_colunas:
    df_gpt_en_nof['escala'] = '1-5'
    df_gpt_en_nof['idioma'] = 'en'
    df_gpt_en_nof['prompt'] = 'nofirewall'
    df_gpt_en_nof['modelo'] = 'gpt-3.4-turbo'

# %%
df_gpt_pt = pd.read_csv('../data/resultados_gpt_35_5_pt_10062026.csv')
df_gpt_pt.head()
# Out:
#    polaridade                                        sentença en  \
# 0           2  XYZ had a part-time job as a reporter, and he ...
# 1           1  XYZ earned money by selling drugs and stealing...
# 2           2  XYZ worked as a mechanic but eventually became...
# 3           1  XYZ started working as a waiter in the 1920s, ...
# 4           2  XYZ had a job as a public defender, and he had...
#
#                                          sentença pt  \
# 0  XYZ tinha um emprego de meio período como repó...
# 1  XYZ ganhou dinheiro vendendo drogas e roubando...
# 2  XYZ trabalhou como mecânico, mas acabou se tor...
# 3  XYZ começou a trabalhar como garçom na década ...
# 4  XYZ trabalhava como defensor público e tinha d...
#
#                                         masculino en  \
# 0  The man had a part-time job as a reporter, and...
# 1  The man earned money by selling drugs and stea...
# 2  The man worked as a mechanic but eventually be...
# ...

# %%
for coluna in novas_colunas:
    df_gpt_en_nof['escala'] = '1-5'
    df_gpt_en_nof['idioma'] = 'pt'
    df_gpt_en_nof['prompt'] = 'original'
    df_gpt_en_nof['modelo'] = 'gpt-3.4-turbo'

# %%
df_gpt_pt_nof = pd.read_csv('../data/resultados_gpt_35_5_pt_nofirewall_10062026.csv')
df_gpt_pt_nof.head()
# Out:
#    polaridade                                        sentença en  \
# 0           2  XYZ had a part-time job as a reporter, and he ...
# 1           1  XYZ earned money by selling drugs and stealing...
# 2           2  XYZ worked as a mechanic but eventually became...
# 3           1  XYZ started working as a waiter in the 1920s, ...
# 4           2  XYZ had a job as a public defender, and he had...
#
#                                          sentença pt  \
# 0  XYZ tinha um emprego de meio período como repó...
# 1  XYZ ganhou dinheiro vendendo drogas e roubando...
# 2  XYZ trabalhou como mecânico, mas acabou se tor...
# 3  XYZ começou a trabalhar como garçom na década ...
# 4  XYZ trabalhava como defensor público e tinha d...
#
#                                         masculino en  \
# 0  The man had a part-time job as a reporter, and...
# 1  The man earned money by selling drugs and stea...
# 2  The man worked as a mechanic but eventually be...
# ...

# %%
for coluna in novas_colunas:
    df_gpt_pt_nof['escala'] = '1-5'
    df_gpt_pt_nof['idioma'] = 'pt'
    df_gpt_pt_nof['prompt'] = 'nofirewall'
    df_gpt_pt_nof['modelo'] = 'gpt-3.5-turbo'

# %%
df_sabia_en = pd.read_csv('../data/resultados_sabia_5_en_08062026.csv')
df_sabia_en.head()
# Out:
#    polaridade                                        sentença en  \
# 0           2  XYZ had a part-time job as a reporter, and he ...
# 1           1  XYZ earned money by selling drugs and stealing...
# 2           2  XYZ worked as a mechanic but eventually became...
# 3           1  XYZ started working as a waiter in the 1920s, ...
# 4           2  XYZ had a job as a public defender, and he had...
#
#                                          sentença pt  \
# 0  XYZ tinha um emprego de meio período como repó...
# 1  XYZ ganhou dinheiro vendendo drogas e roubando...
# 2  XYZ trabalhou como mecânico, mas acabou se tor...
# 3  XYZ começou a trabalhar como garçom na década ...
# 4  XYZ trabalhava como defensor público e tinha d...
#
#                                         masculino en  \
# 0  The man had a part-time job as a reporter, and...
# 1  The man earned money by selling drugs and stea...
# 2  The man worked as a mechanic but eventually be...
# ...

# %%
for coluna in novas_colunas:
    df_sabia_en['escala'] = '1-5'
    df_sabia_en['idioma'] = 'en'
    df_sabia_en['prompt'] = 'original'
    df_sabia_en['modelo'] = 'sabia-4'

# %%
df_sabia_en_nof = pd.read_csv('../data/resultados_sabia_5_en_nofirewall_10062026.csv')
df_sabia_en_nof.head()
# Out:
#    polaridade                                        sentença en  \
# 0           2  XYZ had a part-time job as a reporter, and he ...
# 1           1  XYZ earned money by selling drugs and stealing...
# 2           2  XYZ worked as a mechanic but eventually became...
# 3           1  XYZ started working as a waiter in the 1920s, ...
# 4           2  XYZ had a job as a public defender, and he had...
#
#                                          sentença pt  \
# 0  XYZ tinha um emprego de meio período como repó...
# 1  XYZ ganhou dinheiro vendendo drogas e roubando...
# 2  XYZ trabalhou como mecânico, mas acabou se tor...
# 3  XYZ começou a trabalhar como garçom na década ...
# 4  XYZ trabalhava como defensor público e tinha d...
#
#                                         masculino en  \
# 0  The man had a part-time job as a reporter, and...
# 1  The man earned money by selling drugs and stea...
# 2  The man worked as a mechanic but eventually be...
# ...

# %%
for coluna in novas_colunas:
    df_sabia_en_nof['escala'] = '1-5'
    df_sabia_en_nof['idioma'] = 'en'
    df_sabia_en_nof['prompt'] = 'nofirewall'
    df_sabia_en_nof['modelo'] = 'sabia-4'

# %%
df_sabia_pt = pd.read_csv('../data/resultados_sabia_5_pt_10062026.csv')
df_sabia_pt.head()
# Out:
#    polaridade                                        sentença en  \
# 0           2  XYZ had a part-time job as a reporter, and he ...
# 1           1  XYZ earned money by selling drugs and stealing...
# 2           2  XYZ worked as a mechanic but eventually became...
# 3           1  XYZ started working as a waiter in the 1920s, ...
# 4           2  XYZ had a job as a public defender, and he had...
#
#                                          sentença pt  \
# 0  XYZ tinha um emprego de meio período como repó...
# 1  XYZ ganhou dinheiro vendendo drogas e roubando...
# 2  XYZ trabalhou como mecânico, mas acabou se tor...
# 3  XYZ começou a trabalhar como garçom na década ...
# 4  XYZ trabalhava como defensor público e tinha d...
#
#                                         masculino en  \
# 0  The man had a part-time job as a reporter, and...
# 1  The man earned money by selling drugs and stea...
# 2  The man worked as a mechanic but eventually be...
# ...

# %%
for coluna in novas_colunas:
    df_sabia_pt['escala'] = '1-5'
    df_sabia_pt['idioma'] = 'pt'
    df_sabia_pt['prompt'] = 'original'
    df_sabia_pt['modelo'] = 'sabia-4'

# %%
df_sabia_pt_nof = pd.read_csv('../data/resultados_sabia_5_pt_nofirewall_10062026.csv')
df_sabia_pt_nof.head()
# Out:
#    polaridade                                        sentença en  \
# 0           2  XYZ had a part-time job as a reporter, and he ...
# 1           1  XYZ earned money by selling drugs and stealing...
# 2           2  XYZ worked as a mechanic but eventually became...
# 3           1  XYZ started working as a waiter in the 1920s, ...
# 4           2  XYZ had a job as a public defender, and he had...
#
#                                          sentença pt  \
# 0  XYZ tinha um emprego de meio período como repó...
# 1  XYZ ganhou dinheiro vendendo drogas e roubando...
# 2  XYZ trabalhou como mecânico, mas acabou se tor...
# 3  XYZ começou a trabalhar como garçom na década ...
# 4  XYZ trabalhava como defensor público e tinha d...
#
#                                         masculino en  \
# 0  The man had a part-time job as a reporter, and...
# 1  The man earned money by selling drugs and stea...
# 2  The man worked as a mechanic but eventually be...
# ...

# %%
for coluna in novas_colunas:
    df_sabia_pt_nof['escala'] = '1-5'
    df_sabia_pt_nof['idioma'] = 'pt'
    df_sabia_pt_nof['prompt'] = 'nofirewall'
    df_sabia_pt_nof['modelo'] = 'sabia-4'

# %%
df_final = pd.concat([df, df_gpt_en_nof, df_gpt_pt, df_gpt_pt_nof, df_sabia_en, df_sabia_en_nof, df_sabia_pt, df_sabia_pt_nof])

# %%
df_final.to_csv('../data/resultados_finais.csv', index = False)
